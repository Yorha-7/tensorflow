# %%
import tensorflow as tf
import matplotlib.pyplot as mlt
import pandas as pd
import numpy as np
data=pd.read_csv("used_cars.csv")
model=tf.keras.models.load_model("Car_Price_model.keras")
tensored_data=tf.constant(data)
X=tensored_data[:,:2]
Y=tensored_data[:,2]
for year,milage in X:
    for price in Y:
        prediction=model.predict(np.array([[year,milage]]))
        if prediction < price:
            print("cheap to buy")
        else:
            print("Expensive to buy")
        
suggestion.to_csv("Ai Suggestions",index=False)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 128ms/step
# Expensive to buy
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# cheap to buy
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# cheap to buy
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# Expensive to buy
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# Expensive to buy
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# Expensive to buy
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# Expensive to buy
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# Expensive to buy
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# cheap to buy
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# cheap to buy
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# cheap to buy
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# cheap to buy
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# cheap to buy
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# cheap to buy
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# cheap to buy
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# Expensive to buy
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# cheap to buy
# ...
